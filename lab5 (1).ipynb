# %%
#Import requierd libraries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
sns.set(color_codes=True)

# %%
x = np.linspace(0,10,100)

fig = plt.figure()
plt.plot(x,np.sin(x),'--')
plt.plot(x,np.cos(x),'*')

# %%
from sklearn import datasets
iris=datasets.load_iris()
df= pd.read_csv(iris.filename)
#help(pd.read_csv)
print(iris.filename)
print(iris.feature_names)
df.head(5)
# Out:
# D:\Programs\anaconda\lib\site-packages\sklearn\datasets\data\iris.csv
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %% [markdown]
# <h1>Exercise 1.1</h1>

# %%
df_with_delimiter=pd.read_csv(r'D:\Programs\anaconda\lib\site-packages\sklearn\datasets\data\iris.csv', delimiter=',', header= None,
                             names=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)','Target Class'])

df_with_delimiter.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target Class
# 145             2
# 146             2
# 147             2
# 148             2
# 149             2

# %%
df_with_delimiter.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)  Target Class
# count        150.000000    150.000000
# mean           1.199333      1.000000
# std            0.762238      0.819232
# min            0.100000      0.000000
# 25%            0.300000      0.000000
# 50%            1.300000      1.000000
# 75%            1.800000      2.000000
# max            2.500000      2.000000

# %%
print(df_with_delimiter["Target Class"].value_counts())
# Out:
# 2    50
# 1    50
# 0    50
# Name: Target Class, dtype: int64

# %%
df_with_delimiter["Target Class"].hist()
# Out:
# <AxesSubplot:>

# %%
for ojha, feature in enumerate(list(df_with_delimiter.columns)[:-1]):
    
    fg = sns.FacetGrid(df_with_delimiter, hue='Target Class', height=5)
    
    fg.map(sns.distplot, feature).add_legend()
    
    plt.show()
# Out:
# D:\Programs\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Programs\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.boxplot(x='Target Class',y='petal length (cm)', data=df_with_delimiter)
plt.show()

# %%
sns.violinplot(x='Target Class',y='petal length (cm)', data=df_with_delimiter)
plt.show()

# %%
df_with_delimiter.plot(kind='scatter',x='sepal length (cm)',y='sepal width (cm)', c= 'g')

plt.show()

# %%
sns.set_style("whitegrid");

sns.FacetGrid(df_with_delimiter, hue="Target Class", height=10).map(plt.scatter, "sepal length(cm)", "sepal width (cm)").add_legend();

plt.show();

# %%
sns.set_style("whitegrid");

sns.pairplot(df_with_delimiter,vars = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'], hue = 'Target Class', diag_kind = 'kde', 

       plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'}, height = 2) 

plt.show()
